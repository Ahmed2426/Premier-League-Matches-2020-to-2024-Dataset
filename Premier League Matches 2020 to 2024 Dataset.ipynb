# %% [markdown]
# import Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.linear_model import LinearRegression

# %% [markdown]
# Load data

# %%
df = pd.read_csv("matches.csv")
df
# Out:
#       Unnamed: 0        date           time            comp         round  \
# 0              0  2020-09-21  20:15 (21:15)  Premier League   Matchweek 2
# 1              2  2020-09-27  16:30 (17:30)  Premier League   Matchweek 3
# 2              4  2020-10-03  17:30 (18:30)  Premier League   Matchweek 4
# 3              5  2020-10-17  17:30 (18:30)  Premier League   Matchweek 5
# 4              7  2020-10-24  12:30 (13:30)  Premier League   Matchweek 6
# ...          ...         ...            ...             ...           ...
# 4783          87  2020-07-07  18:00 (19:00)  Premier League  Matchweek 34
# 4784          88  2020-07-11  12:30 (13:30)  Premier League  Matchweek 35
# 4785          89  2020-07-14  20:15 (21:15)  Premier League  Matchweek 36
# 4786          90  2020-07-18  17:30 (18:30)  Premier League  Matchweek 37
# 4787          91  2020-07-26  16:00 (17:00)  Premier League  Matchweek 38
#
#       day venue result  gf  ga  ...  match report  notes  sh  sot  dist fk pk  \
# 0     Mon  Away      W   3   1  ...  Match Report    NaN  13    8  21.1  2  1
# 1     Sun  Home      L   2   5  ...  Match Report    NaN  16    5  19.8  1  0
# 2     Sat  Away      D   1   1  ...  Match Report    NaN  23    1  18.2  1  0
# 3     Sat  Home      W   1   0  ...  Match Report    NaN  13    5  17.7  0  0
# 4     Sat  Away      D   1   1  ...  Match Report    NaN  14    7  20.9  1  0
# ...   ...   ...    ...  ..  ..  ...           ...    ...  ..  ...   ... .. ..
# 4783  Tue  Away      L   1   2  ...  Match Report    NaN  12    3  16.9  1  0
# 4784  Sat  Home      L   0   4  ...  Match Report    NaN  11    2  19.8  1  0
# 4785  Tue  Away      L   0   1  ...  Match Report    NaN   2    0  20.6  0  0
# 4786  Sat  Home      L   0   2  ...  Match Report    NaN   6    2  13.4  0  0
# 4787  Sun  Away      L   0   5  ...  Match Report    NaN   5    4  19.8  0  0
#
#      pkatt season             team
# 0        1   2024  Manchester City
# 1        0   2024  Manchester City
# 2        0   2024  Manchester City
# 3        0   2024  Manchester City
# 4        0   2024  Manchester City
# ...    ...    ...              ...
# 4783     0   2020     Norwich City
# 4784     0   2020     Norwich City
# 4785     0   2020     Norwich City
# 4786     0   2020     Norwich City
# 4787     0   2020     Norwich City
#
# [4788 rows x 28 columns]

# %%
df.head()
# Out:
#    Unnamed: 0        date           time            comp        round  day  \
# 0           0  2020-09-21  20:15 (21:15)  Premier League  Matchweek 2  Mon
# 1           2  2020-09-27  16:30 (17:30)  Premier League  Matchweek 3  Sun
# 2           4  2020-10-03  17:30 (18:30)  Premier League  Matchweek 4  Sat
# 3           5  2020-10-17  17:30 (18:30)  Premier League  Matchweek 5  Sat
# 4           7  2020-10-24  12:30 (13:30)  Premier League  Matchweek 6  Sat
#
#   venue result  gf  ga  ...  match report  notes  sh  sot  dist fk pk pkatt  \
# 0  Away      W   3   1  ...  Match Report    NaN  13    8  21.1  2  1     1
# 1  Home      L   2   5  ...  Match Report    NaN  16    5  19.8  1  0     0
# 2  Away      D   1   1  ...  Match Report    NaN  23    1  18.2  1  0     0
# 3  Home      W   1   0  ...  Match Report    NaN  13    5  17.7  0  0     0
# 4  Away      D   1   1  ...  Match Report    NaN  14    7  20.9  1  0     0
#
#   season             team
# 0   2024  Manchester City
# 1   2024  Manchester City
# 2   2024  Manchester City
# 3   2024  Manchester City
# 4   2024  Manchester City
#
# [5 rows x 28 columns]

# %%
df.tail()
# Out:
#       Unnamed: 0        date           time            comp         round  \
# 4783          87  2020-07-07  18:00 (19:00)  Premier League  Matchweek 34
# 4784          88  2020-07-11  12:30 (13:30)  Premier League  Matchweek 35
# 4785          89  2020-07-14  20:15 (21:15)  Premier League  Matchweek 36
# 4786          90  2020-07-18  17:30 (18:30)  Premier League  Matchweek 37
# 4787          91  2020-07-26  16:00 (17:00)  Premier League  Matchweek 38
#
#       day venue result  gf  ga  ...  match report  notes  sh  sot  dist fk pk  \
# 4783  Tue  Away      L   1   2  ...  Match Report    NaN  12    3  16.9  1  0
# 4784  Sat  Home      L   0   4  ...  Match Report    NaN  11    2  19.8  1  0
# 4785  Tue  Away      L   0   1  ...  Match Report    NaN   2    0  20.6  0  0
# 4786  Sat  Home      L   0   2  ...  Match Report    NaN   6    2  13.4  0  0
# 4787  Sun  Away      L   0   5  ...  Match Report    NaN   5    4  19.8  0  0
#
#      pkatt season          team
# 4783     0   2020  Norwich City
# 4784     0   2020  Norwich City
# 4785     0   2020  Norwich City
# 4786     0   2020  Norwich City
# 4787     0   2020  Norwich City
#
# [5 rows x 28 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4788 entries, 0 to 4787
# Data columns (total 28 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Unnamed: 0    4788 non-null   int64
#  1   date          4788 non-null   object
#  2   time          4788 non-null   object
#  3   comp          4788 non-null   object
#  4   round         4788 non-null   object
#  5   day           4788 non-null   object
#  6   venue         4788 non-null   object
#  7   result        4788 non-null   object
#  8   gf            4788 non-null   int64
#  9   ga            4788 non-null   int64
#  10  opponent      4788 non-null   object
#  11  xg            4788 non-null   float64
#  12  xga           4788 non-null   float64
#  13  poss          4788 non-null   int64
#  14  attendance    3155 non-null   float64
#  15  captain       4788 non-null   object
#  16  formation     4788 non-null   object
#  17  referee       4788 non-null   object
#  18  match report  4788 non-null   object
#  19  notes         0 non-null      float64
#  20  sh            4788 non-null   int64
#  21  sot           4788 non-null   int64
#  22  dist          4786 non-null   float64
#  23  fk            4788 non-null   int64
#  24  pk            4788 non-null   int64
#  25  pkatt         4788 non-null   int64
#  26  season        4788 non-null   int64
#  27  team          4788 non-null   object
# dtypes: float64(5), int64(10), object(13)
# memory usage: 1.0+ MB

# %%
df.describe()
# Out:
#         Unnamed: 0           gf           ga           xg          xga  \
# count  4788.000000  4788.000000  4788.000000  4788.000000  4788.000000
# mean     63.044069     1.447995     1.405388     1.396512     1.364745
# std      42.865191     1.312635     1.286927     0.828847     0.814947
# min       0.000000     0.000000     0.000000     0.000000     0.000000
# 25%      28.000000     0.000000     0.000000     0.800000     0.700000
# 50%      62.000000     1.000000     1.000000     1.300000     1.200000
# 75%      87.000000     2.000000     2.000000     1.900000     1.800000
# max     182.000000     9.000000     9.000000     7.000000     7.000000
#
#               poss    attendance  notes           sh          sot  \
# count  4788.000000   3155.000000    0.0  4788.000000  4788.000000
# mean     50.432957  38397.586688    NaN    12.619256     4.261278
# std      12.810958  17595.849137    NaN     5.548444     2.459963
# min      18.000000   2000.000000    NaN     0.000000     0.000000
# 25%      41.000000  25513.500000    NaN     9.000000     2.000000
# 50%      51.000000  36347.000000    NaN    12.000000     4.000000
# 75%      60.000000  53235.500000    NaN    16.000000     6.000000
# max      82.000000  75546.000000    NaN    36.000000    15.000000
#
#               dist           fk           pk       pkatt       season
# count  4786.000000  4788.000000  4788.000000  4788.00000  4788.000000
# mean     17.356247     0.453216     0.118212     0.14599  2022.365079
# std       3.049341     0.665250     0.342362     0.37937     1.461850
# min       5.300000     0.000000     0.000000     0.00000  2020.000000
# 25%      15.400000     0.000000     0.000000     0.00000  2021.000000
# 50%      17.200000     0.000000     0.000000     0.00000  2023.000000
# 75%      19.100000     1.000000     0.000000     0.00000  2024.000000
# max      39.900000     4.000000     3.000000     3.00000  2024.000000

# %%
df.describe().T
# Out:
#              count          mean           std     min      25%      50%  \
# Unnamed: 0  4788.0     63.044069     42.865191     0.0     28.0     62.0
# gf          4788.0      1.447995      1.312635     0.0      0.0      1.0
# ga          4788.0      1.405388      1.286927     0.0      0.0      1.0
# xg          4788.0      1.396512      0.828847     0.0      0.8      1.3
# xga         4788.0      1.364745      0.814947     0.0      0.7      1.2
# poss        4788.0     50.432957     12.810958    18.0     41.0     51.0
# attendance  3155.0  38397.586688  17595.849137  2000.0  25513.5  36347.0
# notes          0.0           NaN           NaN     NaN      NaN      NaN
# sh          4788.0     12.619256      5.548444     0.0      9.0     12.0
# sot         4788.0      4.261278      2.459963     0.0      2.0      4.0
# dist        4786.0     17.356247      3.049341     5.3     15.4     17.2
# fk          4788.0      0.453216      0.665250     0.0      0.0      0.0
# pk          4788.0      0.118212      0.342362     0.0      0.0      0.0
# pkatt       4788.0      0.145990      0.379370     0.0      0.0      0.0
# season      4788.0   2022.365079      1.461850  2020.0   2021.0   2023.0
#
#                 75%      max
# Unnamed: 0     87.0    182.0
# gf              2.0      9.0
# ga              2.0      9.0
# xg              1.9      7.0
# xga             1.8      7.0
# poss           60.0     82.0
# attendance  53235.5  75546.0
# notes           NaN      NaN
# sh             16.0     36.0
# sot             6.0     15.0
# dist           19.1     39.9
# fk              1.0      4.0
# pk              0.0      3.0
# pkatt           0.0      3.0
# season       2024.0   2024.0

# %%
df.isnull().sum()
# Out:
# Unnamed: 0         0
# date               0
# time               0
# comp               0
# round              0
# day                0
# venue              0
# result             0
# gf                 0
# ga                 0
# opponent           0
# xg                 0
# xga                0
# poss               0
# attendance      1633
# captain            0
# formation          0
# referee            0
# match report       0
# notes           4788
# sh                 0
# sot                0
# dist               2
# fk                 0
# pk                 0
# pkatt              0
# season             0
# team               0
# dtype: int64

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'date', 'time', 'comp', 'round', 'day', 'venue', 'result',
#        'gf', 'ga', 'opponent', 'xg', 'xga', 'poss', 'attendance', 'captain',
#        'formation', 'referee', 'match report', 'notes', 'sh', 'sot', 'dist',
#        'fk', 'pk', 'pkatt', 'season', 'team'],
#       dtype='object')

# %%
df['date'] = pd.to_datetime(df['date'], errors='coerce')  # تحويل عمود التاريخ إلى datetime

# %%
numeric_columns = ['gf', 'ga', 'xg', 'xga', 'poss', 'sh', 'sot', 'dist', 'fk', 'pk', 'pkatt']
for col in numeric_columns:
    df[col] = pd.to_numeric(df[col], errors='coerce')

# %%
df.isnull().sum()
# Out:
# Unnamed: 0         0
# date               0
# time               0
# comp               0
# round              0
# day                0
# venue              0
# result             0
# gf                 0
# ga                 0
# opponent           0
# xg                 0
# xga                0
# poss               0
# attendance      1633
# captain            0
# formation          0
# referee            0
# match report       0
# notes           4788
# sh                 0
# sot                0
# dist               2
# fk                 0
# pk                 0
# pkatt              0
# season             0
# team               0
# dtype: int64

# %%
df[numeric_columns] = df[numeric_columns].fillna(df[numeric_columns].mean())

# %%
print(df.describe())
# Out:
#         Unnamed: 0                           date           gf           ga  \
# count  4788.000000                           4788  4788.000000  4788.000000
# mean     63.044069  2021-10-14 00:14:08.120300800     1.447995     1.405388
# min       0.000000            2019-08-09 00:00:00     0.000000     0.000000
# 25%      28.000000            2020-10-24 00:00:00     0.000000     0.000000
# 50%      62.000000            2021-05-13 00:00:00     1.000000     1.000000
# 75%      87.000000            2022-12-31 00:00:00     2.000000     2.000000
# max     182.000000            2024-05-19 00:00:00     9.000000     9.000000
# std      42.865191                            NaN     1.312635     1.286927
#
#                 xg          xga         poss    attendance  notes  \
# count  4788.000000  4788.000000  4788.000000   3155.000000    0.0
# mean      1.396512     1.364745    50.432957  38397.586688    NaN
# min       0.000000     0.000000    18.000000   2000.000000    NaN
# 25%       0.800000     0.700000    41.000000  25513.500000    NaN
# 50%       1.300000     1.200000    51.000000  36347.000000    NaN
# 75%       1.900000     1.800000    60.000000  53235.500000    NaN
# max       7.000000     7.000000    82.000000  75546.000000    NaN
# std       0.828847     0.814947    12.810958  17595.849137    NaN
#
#                 sh          sot         dist           fk           pk  \
# count  4788.000000  4788.000000  4788.000000  4788.000000  4788.000000
# mean     12.619256     4.261278    17.356247     0.453216     0.118212
# min       0.000000     0.000000     5.300000     0.000000     0.000000
# 25%       9.000000     2.000000    15.400000     0.000000     0.000000
# 50%      12.000000     4.000000    17.200000     0.000000     0.000000
# 75%      16.000000     6.000000    19.100000     1.000000     0.000000
# max      36.000000    15.000000    39.900000     4.000000     3.000000
# std       5.548444     2.459963     3.048704     0.665250     0.342362
#
#             pkatt       season
# count  4788.00000  4788.000000
# mean      0.14599  2022.365079
# min       0.00000  2020.000000
# 25%       0.00000  2021.000000
# 50%       0.00000  2023.000000
# 75%       0.00000  2024.000000
# max       3.00000  2024.000000
# std       0.37937     1.461850

# %%
a=df["attendance"].mean()
df["attendance"].fillna(a,inplace=True)
df.isnull().sum()
# Out:
# Unnamed: 0         0
# date               0
# time               0
# comp               0
# round              0
# day                0
# venue              0
# result             0
# gf                 0
# ga                 0
# opponent           0
# xg                 0
# xga                0
# poss               0
# attendance         0
# captain            0
# formation          0
# referee            0
# match report       0
# notes           4788
# sh                 0
# sot                0
# dist               0
# fk                 0
# pk                 0
# pkatt              0
# season             0
# team               0
# dtype: int64

# %%
as_df =df.fillna(0)
as_df
# Out:
#       Unnamed: 0       date           time            comp         round  day  \
# 0              0 2020-09-21  20:15 (21:15)  Premier League   Matchweek 2  Mon
# 1              2 2020-09-27  16:30 (17:30)  Premier League   Matchweek 3  Sun
# 2              4 2020-10-03  17:30 (18:30)  Premier League   Matchweek 4  Sat
# 3              5 2020-10-17  17:30 (18:30)  Premier League   Matchweek 5  Sat
# 4              7 2020-10-24  12:30 (13:30)  Premier League   Matchweek 6  Sat
# ...          ...        ...            ...             ...           ...  ...
# 4783          87 2020-07-07  18:00 (19:00)  Premier League  Matchweek 34  Tue
# 4784          88 2020-07-11  12:30 (13:30)  Premier League  Matchweek 35  Sat
# 4785          89 2020-07-14  20:15 (21:15)  Premier League  Matchweek 36  Tue
# 4786          90 2020-07-18  17:30 (18:30)  Premier League  Matchweek 37  Sat
# 4787          91 2020-07-26  16:00 (17:00)  Premier League  Matchweek 38  Sun
#
#      venue result  gf  ga  ...  match report  notes  sh  sot  dist fk pk  \
# 0     Away      W   3   1  ...  Match Report    0.0  13    8  21.1  2  1
# 1     Home      L   2   5  ...  Match Report    0.0  16    5  19.8  1  0
# 2     Away      D   1   1  ...  Match Report    0.0  23    1  18.2  1  0
# 3     Home      W   1   0  ...  Match Report    0.0  13    5  17.7  0  0
# 4     Away      D   1   1  ...  Match Report    0.0  14    7  20.9  1  0
# ...    ...    ...  ..  ..  ...           ...    ...  ..  ...   ... .. ..
# 4783  Away      L   1   2  ...  Match Report    0.0  12    3  16.9  1  0
# 4784  Home      L   0   4  ...  Match Report    0.0  11    2  19.8  1  0
# 4785  Away      L   0   1  ...  Match Report    0.0   2    0  20.6  0  0
# 4786  Home      L   0   2  ...  Match Report    0.0   6    2  13.4  0  0
# 4787  Away      L   0   5  ...  Match Report    0.0   5    4  19.8  0  0
#
#      pkatt season             team
# 0        1   2024  Manchester City
# 1        0   2024  Manchester City
# 2        0   2024  Manchester City
# 3        0   2024  Manchester City
# 4        0   2024  Manchester City
# ...    ...    ...              ...
# 4783     0   2020     Norwich City
# 4784     0   2020     Norwich City
# 4785     0   2020     Norwich City
# 4786     0   2020     Norwich City
# 4787     0   2020     Norwich City
#
# [4788 rows x 28 columns]

# %% [markdown]
# Analyze the frequency distribution of unique values in some text columns

# %%
print("Distribution of competitions:")
print(df['comp'].value_counts())
# Out:
# Distribution of competitions:
# comp
# Premier League    4788
# Name: count, dtype: int64

# %%
print("Distribution of rounds:")
print(df['round'].value_counts())
# Out:
# Distribution of rounds:
# round
# Matchweek 2     126
# Matchweek 33    126
# Matchweek 23    126
# Matchweek 24    126
# Matchweek 16    126
# Matchweek 25    126
# Matchweek 26    126
# Matchweek 29    126
# Matchweek 27    126
# Matchweek 28    126
# Matchweek 3     126
# Matchweek 30    126
# Matchweek 31    126
# Matchweek 32    126
# Matchweek 34    126
# Matchweek 35    126
# Matchweek 36    126
# Matchweek 37    126
# Matchweek 22    126
# Matchweek 21    126
# Matchweek 20    126
# Matchweek 1     126
# Matchweek 4     126
# Matchweek 5     126
# Matchweek 6     126
# Matchweek 7     126
# Matchweek 8     126
# Matchweek 9     126
# Matchweek 10    126
# Matchweek 11    126
# Matchweek 12    126
# Matchweek 13    126
# Matchweek 14    126
# Matchweek 15    126
# Matchweek 17    126
# Matchweek 18    126
# Matchweek 19    126
# Matchweek 38    126
# Name: count, dtype: int64

# %%
print("Distribution of venues:")
print(df['venue'].value_counts())
# Out:
# Distribution of venues:
# venue
# Away    2394
# Home    2394
# Name: count, dtype: int64

# %%
print("Distribution of captains:")
print(df['captain'].value_counts())
# Out:
# Distribution of captains:
# captain
# Lewis Dunk           200
# Kasper Schmeichel    181
# Hugo Lloris          179
# James Ward-Prowse    162
# César Azpilicueta    160
#                     ...
# Ezri Konsa             1
# Yerry Mina             1
# Asmir Begović          1
# Jack Cork              1
# Timm Klose             1
# Name: count, Length: 178, dtype: int64

# %%
print("Distribution of referees:")
print(df['referee'].value_counts())
# Out:
# Distribution of referees:
# referee
# Anthony Taylor       371
# Michael Oliver       359
# Paul Tierney         316
# Craig Pawson         284
# Stuart Attwell       269
# Chris Kavanagh       261
# Martin Atkinson      240
# David Coote          236
# Andre Marriner       229
# Mike Dean            225
# Jonathan Moss        219
# Andy Madley          215
# Simon Hooper         208
# Kevin Friend         197
# Peter Bankes         173
# Robert Jones         158
# Graham Scott         149
# Darren England       136
# Jarred Gillett        94
# John Brooks           90
# Lee Mason             85
# Michael Salisbury     64
# Tim Robinson          48
# Thomas Bramall        38
# Tony Harrington       38
# Samuel Barrott        30
# Darren Bond           18
# Joshua Smith          10
# Samuel Allison         6
# Oliver Langford        4
# Lewis Smith            4
# Robert Madley          4
# Rebecca Welch          4
# Matt Donohue           4
# Sunny Singh            2
# Name: count, dtype: int64

# %%
results_distribution = df['result'].value_counts(normalize=True) * 100
print("Results distribution (Win, Loss, Draw):")
print(results_distribution)
# Out:
# Results distribution (Win, Loss, Draw):
# result
# W    39.578112
# L    38.011696
# D    22.410192
# Name: proportion, dtype: float64

# %%
venue_grouped = df.groupby('venue')['gf'].agg(['mean', 'std', 'count'])
print("Goals statistics by venue:")
print(venue_grouped)
# Out:
# Goals statistics by venue:
#            mean       std  count
# venue
# Away   1.336257  1.257873   2394
# Home   1.559733  1.356287   2394

# %%
referee_grouped = df.groupby('referee')['gf'].agg(['mean', 'std', 'count'])
print("Goals statistics by referee:")
print(referee_grouped)
# Out:
# Goals statistics by referee:
#                        mean       std  count
# referee
# Andre Marriner     1.502183  1.473820    229
# Andy Madley        1.483721  1.446383    215
# Anthony Taylor     1.541779  1.269286    371
# Chris Kavanagh     1.398467  1.244309    261
# Craig Pawson       1.394366  1.304831    284
# Darren Bond        1.333333  1.371989     18
# Darren England     1.441176  1.359546    136
# David Coote        1.368644  1.222011    236
# Graham Scott       1.389262  1.277198    149
# Jarred Gillett     1.638298  1.310430     94
# John Brooks        1.244444  1.173788     90
# Jonathan Moss      1.529680  1.411871    219
# Joshua Smith       1.700000  1.494434     10
# Kevin Friend       1.406091  1.316134    197
# Lee Mason          1.400000  1.338087     85
# Lewis Smith        1.500000  1.290994      4
# Martin Atkinson    1.275000  1.337971    240
# Matt Donohue       2.250000  1.258306      4
# Michael Oliver     1.676880  1.273404    359
# Michael Salisbury  1.562500  1.206793     64
# Mike Dean          1.328889  1.523129    225
# Oliver Langford    1.000000  0.000000      4
# Paul Tierney       1.439873  1.296953    316
# Peter Bankes       1.242775  1.033743    173
# Rebecca Welch      1.000000  0.816497      4
# Robert Jones       1.316456  1.140391    158
# Robert Madley      1.500000  0.577350      4
# Samuel Allison     2.166667  1.471960      6
# Samuel Barrott     1.833333  1.391683     30
# Simon Hooper       1.519231  1.340422    208
# Stuart Attwell     1.468401  1.325667    269
# Sunny Singh        1.000000  0.000000      2
# Thomas Bramall     1.315789  1.187895     38
# Tim Robinson       1.458333  1.320192     48
# Tony Harrington    1.526316  1.246332     38

# %%
missing_values = df.isnull().sum()
print("Missing values in each column:")
print(missing_values)
# Out:
# Missing values in each column:
# Unnamed: 0         0
# date               0
# time               0
# comp               0
# round              0
# day                0
# venue              0
# result             0
# gf                 0
# ga                 0
# opponent           0
# xg                 0
# xga                0
# poss               0
# attendance         0
# captain            0
# formation          0
# referee            0
# match report       0
# notes           4788
# sh                 0
# sot                0
# dist               0
# fk                 0
# pk                 0
# pkatt              0
# season             0
# team               0
# dtype: int64

# %%
missing_percentage = (missing_values / len(df)) * 100
print("Percentage of missing values in each column:")
print(missing_percentage)
# Out:
# Percentage of missing values in each column:
# Unnamed: 0        0.0
# date              0.0
# time              0.0
# comp              0.0
# round             0.0
# day               0.0
# venue             0.0
# result            0.0
# gf                0.0
# ga                0.0
# opponent          0.0
# xg                0.0
# xga               0.0
# poss              0.0
# attendance        0.0
# captain           0.0
# formation         0.0
# referee           0.0
# match report      0.0
# notes           100.0
# sh                0.0
# sot               0.0
# dist              0.0
# fk                0.0
# pk                0.0
# pkatt             0.0
# season            0.0
# team              0.0
# dtype: float64

# %%
numeric_df = df.select_dtypes(include=['float64', 'int64'])
numeric_df = numeric_df.apply(pd.to_numeric, errors='coerce')
print(numeric_df.info())

# %%
numeric_df = numeric_df.dropna()

# %%
correlation_matrix = numeric_df.corr()
print("Correlation matrix:")
print(correlation_matrix)
# Out:
# Correlation matrix:
#             Unnamed: 0  gf  ga  xg  xga  poss  attendance  notes  sh  sot  \
# Unnamed: 0         NaN NaN NaN NaN  NaN   NaN         NaN    NaN NaN  NaN
# gf                 NaN NaN NaN NaN  NaN   NaN         NaN    NaN NaN  NaN
# ga                 NaN NaN NaN NaN  NaN   NaN         NaN    NaN NaN  NaN
# xg                 NaN NaN NaN NaN  NaN   NaN         NaN    NaN NaN  NaN
# xga                NaN NaN NaN NaN  NaN   NaN         NaN    NaN NaN  NaN
# poss               NaN NaN NaN NaN  NaN   NaN         NaN    NaN NaN  NaN
# attendance         NaN NaN NaN NaN  NaN   NaN         NaN    NaN NaN  NaN
# notes              NaN NaN NaN NaN  NaN   NaN         NaN    NaN NaN  NaN
# sh                 NaN NaN NaN NaN  NaN   NaN         NaN    NaN NaN  NaN
# sot                NaN NaN NaN NaN  NaN   NaN         NaN    NaN NaN  NaN
# dist               NaN NaN NaN NaN  NaN   NaN         NaN    NaN NaN  NaN
# fk                 NaN NaN NaN NaN  NaN   NaN         NaN    NaN NaN  NaN
# pk                 NaN NaN NaN NaN  NaN   NaN         NaN    NaN NaN  NaN
# pkatt              NaN NaN NaN NaN  NaN   NaN         NaN    NaN NaN  NaN
# season             NaN NaN NaN NaN  NaN   NaN         NaN    NaN NaN  NaN
#
#             dist  fk  pk  pkatt  season
# Unnamed: 0   NaN NaN NaN    NaN     NaN
# gf           NaN NaN NaN    NaN     NaN
# ga           NaN NaN NaN    NaN     NaN
# xg           NaN NaN NaN    NaN     NaN
# xga          NaN NaN NaN    NaN     NaN
# poss         NaN NaN NaN    NaN     NaN
# attendance   NaN NaN NaN    NaN     NaN
# notes        NaN NaN NaN    NaN     NaN
# sh           NaN NaN NaN    NaN     NaN
# sot          NaN NaN NaN    NaN     NaN
# dist         NaN NaN NaN    NaN     NaN
# fk           NaN NaN NaN    NaN     NaN
# pk           NaN NaN NaN    NaN     NaN
# pkatt        NaN NaN NaN    NaN     NaN
# season       NaN NaN NaN    NaN     NaN

# %%
X = df[['poss', 'sh', 'sot']]  
y = df['xg']  
model = LinearRegression()
model.fit(X, y)
print("Coefficients:", model.coef_)
print("Intercept:", model.intercept_)
# Out:
# Coefficients: [-0.00072092  0.06976068  0.11259278]
# Intercept: 0.07275317586850472

# %%
from scipy.stats import kstes
stat, p_value = kstest(df['gf'], 'norm')
print(f"KS test statistic: {stat}, p-value: {p_value}")
# Out:
# KS test statistic: 0.5763071520835805, p-value: 0.0

# %%
conditional_analysis = df.groupby(['venue', 'round'])['result'].value_counts(normalize=True)
print(conditional_analysis)
# Out:
# venue  round         result
# Away   Matchweek 1   W         0.451613
#                      L         0.419355
#                      D         0.129032
#        Matchweek 10  W         0.453125
#                      L         0.359375
#                                  ...
# Home   Matchweek 8   L         0.338710
#                      D         0.225806
#        Matchweek 9   W         0.437500
#                      L         0.281250
#                      D         0.281250
# Name: proportion, Length: 228, dtype: float64

# %%
df['date'] = pd.to_datetime(df['date'])
df.set_index('date', inplace=True)
print(df['gf'].resample('M').mean())
# Out:
# date
# 2019-08-31    1.555556
# 2019-09-30    1.759036
# 2019-10-31    1.512821
# 2019-11-30    1.553191
# 2019-12-31    1.484663
# 2020-01-31    1.383178
# 2020-02-29    1.311828
# 2020-03-31    1.312500
# 2020-04-30         NaN
# 2020-05-31         NaN
# 2020-06-30    1.272727
# 2020-07-31    1.630058
# 2020-08-31         NaN
# 2020-09-30    1.839286
# 2020-10-31    1.426471
# 2020-11-30    1.250000
# 2020-12-31    1.263158
# 2021-01-31    1.200000
# 2021-02-28    1.259615
# 2021-03-31    1.121212
# 2021-04-30    1.448718
# 2021-05-31    1.490196
# 2021-06-30         NaN
# 2021-07-31         NaN
# 2021-08-31    1.416667
# 2021-09-30    1.216667
# 2021-10-31    1.551282
# 2021-11-30    1.296875
# 2021-12-31    1.500000
# 2022-01-31    1.403226
# 2022-02-28    1.250000
# 2022-03-31    1.406250
# 2022-04-30    1.340000
# 2022-05-31    1.630952
# 2022-06-30         NaN
# 2022-07-31         NaN
# 2022-08-31    1.448980
# 2022-09-30    1.555556
# 2022-10-31    1.313559
# 2022-11-30    1.650000
# 2022-12-31    1.472222
# 2023-01-31    1.128571
# 2023-02-28    1.162500
# 2023-03-31    1.483871
# 2023-04-30    1.653226
# 2023-05-31    1.489583
# 2023-06-30         NaN
# 2023-07-31         NaN
# 2023-08-31    1.482759
# 2023-09-30    1.578947
# 2023-10-31    1.469697
# 2023-11-30    1.683333
# 2023-12-31    1.560606
# 2024-01-31    1.650000
# 2024-02-29    1.880952
# 2024-03-31    1.642857
# 2024-04-30    1.688679
# 2024-05-31    1.735294
# Freq: M, Name: gf, dtype: float64

# %% [markdown]
# Information visualization

# %%
plt.figure(figsize=(10, 6))
plt.hist(df['gf'].dropna(), bins=20, edgecolor='k', alpha=0.7)
plt.title('Distribution of Goals (gf)')
plt.xlabel('Goals')
plt.ylabel('Frequency')
plt.show()

# %%
plt.figure(figsize=(12, 6))
sns.barplot(x='round', y='gf', data=df)
plt.title('Goals (gf) Distribution by Round')
plt.xlabel('Round')
plt.ylabel('Goals')
plt.xticks(rotation=45)
plt.show()

# %%
selected_features = df[['gf', 'ga', 'xg', 'xga', 'poss']]

plt.figure(figsize=(12, 10))
sns.pairplot(selected_features)
plt.title('Pair Plot of Selected Features')
plt.show()
# Out:
# E:\anaconda\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
plt.figure(figsize=(12, 6))
sns.countplot(x='venue', data=df, order=df['venue'].value_counts().index)
plt.title('Count of Matches by Venue')
plt.xlabel('Venue')
plt.ylabel('Count')
plt.xticks(rotation=45)
plt.show()

# %%
plt.figure(figsize=(8, 8))
venue_counts = df['venue'].value_counts()
plt.pie(venue_counts, labels=venue_counts.index, autopct='%1.1f%%', startangle=140)
plt.title('Distribution of Matches by Venue')
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.regplot(x='poss', y='gf', data=df)
plt.title('Regression Plot of Goals (gf) vs Possession')
plt.xlabel('Possession (%)')
plt.ylabel('Goals')
plt.show()

# %%
plt.figure(figsize=(14, 7))
df['gf'].resample('M').mean().plot()
plt.title('Monthly Average Goals (gf)')
plt.xlabel('Date')
plt.ylabel('Average Goals')
plt.grid(True)
plt.show()

# %%
data = pd.DataFrame({
    'round': np.random.choice(['Round 1', 'Round 2', 'Round 3'], size=100),
    'venue': np.random.choice(['Stadium A', 'Stadium B', 'Stadium C'], size=100),
    'gf': np.random.randint(0, 5, size=100)
})
heatmap_data = data.pivot_table(index='round', columns='venue', values='gf', aggfunc='mean')
plt.figure(figsize=(10, 7))
sns.heatmap(heatmap_data, annot=True, cmap='coolwarm', vmin=0, vmax=5)
plt.title('Average Goals by Round and Venue')
plt.xlabel('Venue')
plt.ylabel('Round')
plt.show()

# %%
performance_data = df[['gf', 'xg', 'sh', 'sot', 'poss']].corr()

plt.figure(figsize=(10, 8))
sns.heatmap(performance_data, annot=True, cmap='coolwarm', vmin=-1, vmax=1)
plt.title('Correlation Heatmap of Performance Metrics')
plt.show()

# %%
g = sns.FacetGrid(df, col='team', col_wrap=3, height=4)
g.map_dataframe(sns.scatterplot, x='xg', y='gf')
g.set_axis_labels('Expected Goals (xg)', 'Goals (gf)')
g.set_titles(col_template="{col_name}")
plt.show()
# Out:
# E:\anaconda\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.pairplot(df[['gf', 'xg', 'sh', 'sot', 'poss']])
plt.show()
# Out:
# E:\anaconda\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %% [markdown]
# Thank you so much for watching the project to the end
